# %%
# !pwd
# Out:
# /content

# %%
import os

os.chdir('/content/drive/My Drive/Colab Notebooks/ML/Grooking-Machine-Learning')

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/ML/Grooking-Machine-Learning
