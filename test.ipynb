# %% [markdown]
# <a href="https://colab.research.google.com/github/ATP-IKO/Grooking-Machine-Learning/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello testing123!!!")
# Out:
# Hello testing123!!!

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive/mydrive/')
# Out:
# Mounted at /content/drive
